# %%
lumiere_allumee = True

if lumiere_allumee:
    print("Il fait clair.")
else:
    print("Il fait noir.")
# Out:
# Il fait clair.

# %%
a = float(input("Chiffre 1"))
b = float(input("Chiffre 2"))
c = float(input("Chiffre 3"))

total = a + b + c
moyenne = total / 3
print(moyenne)
# Out:
# 23.333333333333332

# %%
facture = 72
pourboire_pourcent = float(input("Pourboire désiré?"))
pourboire = pourboire_pourcent / 100 * facture
total = facture + pourboire

print("Pourboire: " + str(pourboire)+"$")
print("Total: " + str(total)+"$")
# Out:
# Pourboire: 7.2$
# Total: 79.2$

# %%
nom = "Julien"
chats = 2
sommeil = 7.5
enseigne = True

phrase = "Mon nom est " + nom + ", j'ai " + str(chats) + " chats, dormi " + str(sommeil) + "h et le fait que j'enseigne la programmation est: " + str(enseigne)
print(phrase)
# Out:
# Mon nom est Julien, j'ai 2 chats, dormi 7.5h et le fait que j'enseigne la programmation est: True

# %%
celcius = float(input("Celcius"))
fahrenheit = (celcius * (9/5)) + 32
print(fahrenheit)
# Out:
# 23.0

# %%
a = 20
b = 100
c = a
a = b
b = c

print(a)
print(b)
# Out:
# 100
# 20

# %%
pts_a_ce_jour = float(input("Points à ce jour"))
pts_total = float(input("Points total"))

pts_restants = 100 - pts_total
pts_manquants = 60 - pts_a_ce_jour
moyenne = pts_manquants / pts_restants

print(moyenne * 100)
# Out:
# 56.666666666666664

# %%
secondes = int(input("Secondes"))
heures = secondes / 60 / 60

if heures >= 6 and heures <= 18:
    print("jour")
else:
    print("soir")
# Out:
# jour

# %%
import math

a = float(input("a"))
b = float(input("b"))
c = float(input("c"))

commun = math.sqrt(b**2 - 4*a*c)
version_plus = (-b + commun) / (2*a)
version_moins = (-b - commun) / (2*a)

print("+: " + str(version_plus))
print("-: " + str(version_moins))
# Out:
# +: 0.9067177514850918
# -: -2.5733844181517584
