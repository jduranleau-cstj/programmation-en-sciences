# %%
import matplotlib.pyplot as plt
import numpy as np
import random

precedant = rng.integers(0, 2, 50 * 50).reshape(50, 50)

fig = plt.figure()
ax = fig.subplots()

for etape in range(4):
    
    resultat = np.zeros([50, 50])
    
    for y in range(50):
        for x in range(50):
            if precedant[y][x] == 1:
                resultat[y][x] = 1
    
    precedant = resultat
    
    plt.imshow(resultat, cmap="binary")
    plt.show()
