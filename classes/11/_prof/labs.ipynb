# %%
import numpy as np

nums = np.arange(10, 15, 0.5)

for n in nums:
    print(n)
# Out:
# 10.0
# 10.5
# 11.0
# 11.5
# 12.0
# 12.5
# 13.0
# 13.5
# 14.0
# 14.5

# %%
import numpy as np

n = int(input())

nums = np.linspace(0, np.pi * 2, n)

print(nums)
# Out:
#  10
# [0.         0.6981317  1.3962634  2.0943951  2.7925268  3.4906585
#  4.1887902  4.88692191 5.58505361 6.28318531]

# %%
import numpy as np
import matplotlib.pyplot as plt

pxs = np.random.uniform(0, 1, 100).reshape(10, 10)

plt.imshow(pxs)

# %%
import numpy as np

nums = np.array([942, 245, 683, 658, 612, 305, 766, 687, 249, 923,  35, 374, 468,
901, 531, 109,  74, 578, 110, 987, 569, 712, 394, 800, 250, 344,
16, 929, 786, 762, 746, 880, 828, 981, 276, 186, 525, 493, 844,
691, 564, 661, 829, 109, 847,  67,   0, 186, 391, 105, 684, 844,
681, 434, 453, 326, 718, 990, 210, 994, 691, 598,  34, 899, 212,
841, 637, 923, 172, 177, 200, 721, 740,   1, 549, 123,  48, 164,
400, 306, 452, 808, 951, 675, 500, 291, 450, 613, 928, 792, 831,
552, 928, 398, 205, 649, 841, 780,   2, 781])

nums *= 2

n = 0

for num in nums:
    if num > 1000:
        n += 1

print(n)
# Out:
# 56

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(np.random.uniform(0, 10, 1000), np.random.uniform(0, 10, 1000), ".")

plt.show()

# %%
import random

with open("output.txt", "w") as f:
    for i in range(100000):
        n = random.uniform(0, 100)
        f.write(str(n)+"\n")

# %%
syllabes = ["a", "e", "cha", "ba", "re"]
picks = np.random.choice(syllabes, 4)
nom = ""

for pick in picks:
    nom += pick
    
print(nom)
# Out:
# chaaea
