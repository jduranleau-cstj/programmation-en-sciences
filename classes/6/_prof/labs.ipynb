# %%
import random

n1 = random.randint(0, 10)
n2 = random.randint(0, 10)

print(f"Les nombres sont {n1} et {n2}")
# Out:
# Les nombres sont 8 et 3

# %%
nom = input("Entrez votre nom:")

with open("noms.txt", "a") as f:
    f.write("\n" + nom)
# Out:
# Entrez votre nom: Amélie

# %%
with open("noms.txt") as f:
    lignes = f.readlines()
    for ligne in lignes:
        nom = ligne.strip()
        print("👤 " + nom)
# Out:
# 👤 Julien
# 👤 Iris
# 👤 Amélie

# %%
import csv

plus_grand = 0

with open("liste_a.csv") as f:
    lignes = csv.reader(f)
    
    for ligne in lignes:
        n = int(ligne[0])
        
        if n > plus_grand:
            plus_grand = n

    print(plus_grand)
# Out:
# 99998749

# %%
import csv

total = 0
qty = 0

with open("liste_a.csv") as f:
    lignes = csv.reader(f)
    
    for ligne in lignes:
        n = int(ligne[0])
        total += n
        qty += 1

    print(qty)
    print(total / qty)
# Out:
# 11059
# 49860527.51198119

# %%
import csv

plus_petit = 999999
plus_grand = 0

with open("liste_a.csv") as f:
    lignes = csv.reader(f)
    
    for ligne in lignes:
        n = int(ligne[0])

        if n < plus_petit:
            plus_petit = n
            
        if n > plus_grand:
            plus_grand = n

    print(plus_grand)
    print(plus_petit)
    print(plus_grand - plus_petit)
# Out:
# 99998749
# 3852
# 99994897

# %%
import random

with open("nombres.txt", "a") as f:
    for i in range(500):
        n = random.randint(0, 100)
        f.write(str(n) + "\n")
