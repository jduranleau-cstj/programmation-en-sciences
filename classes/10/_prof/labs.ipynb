# %%
cours = {
    "titre": "Programmation en sciences",
    "numero": 101,
    "enseignant": "Julien Duranleau",
    "nb_eleves": 23,
}

phrase = f"Le groupe {cours["numero"]} du cours de {cours["titre"]} donné par {cours["enseignant"]} contient {cours["nb_eleves"]} élèves."

print(phrase)
# Out:
# Le groupe 101 du cours de Programmation en sciences donné par Julien Duranleau contient 23 élèves.

# %%
import random

inventaire = {"pomme": 5, "banane": 12, "champignon": 2}

inventaire["pomme"] += random.randint(0, 5)

print(inventaire)
# Out:
# {'pomme': 6, 'banane': 12, 'champignon': 2}

# %%
fruits = {"pomme": 5, "banane": 2, "fraise": 12}

nom = input("Fruit:")

if nom in fruits:
    print("Fruit disponible")
else:
    print("Rupture de stock")
# Out:
# Rupture de stock

# %%
fruits = {"pomme": 5, "banane": 2, "fraise": 12}

for fruit in fruits:
    if fruits[fruit] > 1:
        print(f"Il reste {fruits[fruit]} {fruit}s.")
    else:
        print(f"Il reste {fruits[fruit]} {fruit}.")
# Out:
# Il reste 5 pommes.
# Il reste 2 bananes.
# Il reste 12 fraises.

# %%
texte = "Attack the dog then pretend like nothing happened cats are a queer kind of folk my water bowl is clean and freshly replenished, so i'll drink from the toilet or to pet a cat, rub its belly, endure blood and agony, quietly weep, keep rubbing belly purr as loud as possible, be the most annoying cat that you can, and, knock everything off the table or fall over dead (not really but gets sypathy), flex claws on the human's belly and purr like a lawnmower."
lettres = {}

for lettre in texte:
    if lettre in lettres:
        lettres[lettre] += 1
    else:
        lettres[lettre] = 1

for lettre in lettres:
    print(f"{lettre}: {lettres[lettre]}")
# Out:
# A: 1
# t: 29
# a: 29
# c: 8
# k: 9
#  : 84
# h: 14
# e: 44
# d: 15
# o: 25
# g: 7
# n: 26
# p: 11
# r: 21
# l: 28
# i: 15
# s: 15
# q: 2
# u: 11
# f: 8
# m: 5
# y: 13
# w: 6
# b: 12
# ,: 9
# ': 2
# v: 2
# (: 1
# ): 1
# x: 1
# .: 1

# %%
liste = ["chat", "chien", "chat", "oiseau", "chien", "chat", "chat", "chien", "chat", "chien", "chat", "oiseau", "chien", "chat", "oiseau", "chien", "chat"]
mots = {}

for mot in liste:
    if mot in mots:
        mots[mot] += 1
    else:
        mots[mot] = 1

print(mots)
# Out:
# {'chat': 8, 'chien': 6, 'oiseau': 3}

# %%
noms = {"Paul": 60, "Marie": 22, "Jean": 41, "Sophie": 19, "Arnold": 75}

nouveau = {}

for nom in noms:
    if nom[0] != "A" and nom[0] != "M":
        nouveau[nom] = noms[nom]

print(nouveau)
# Out:
# {'Paul': 60, 'Jean': 41, 'Sophie': 19}
