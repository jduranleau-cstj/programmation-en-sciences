# %%
somme = 50 - 8 * 10
print(somme)
# Out:
# -30

# %%
print(type(10))
print(type(42.5151258))
print(type(-5))
print(type(0))
print(type("test"))
print(type(True))
print(type(0.0))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>

# %%
resultat = 17 * 4.5
resultat = resultat * 100
print(resultat)
# Out:
# 7650.0

# %%
a = 45
b = 68
c = 180 - b - a
print(c)
# Out:
# 67

# %%
import math

x1 = 0
y1 = 0
x2 = 1
y2 = 1

distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
print(distance)
# Out:
# 1.4142135623730951

# %%
d = 10
r = d / 2
volume = 4/3*math.pi*r**3
print(volume)
# Out:
# 523.5987755982989

# %%
animal = "L'écurieuil"
action = "saute"
phrase = animal + " " + action
print(phrase)
# Out:
# L'écurieuil saute

# %%
repetition = 3
phrase = "Ha" + "ha" * (repetition - 1)
print(phrase)
# Out:
# Hahaha

# %%
largeur = 10

print("#" * largeur)
print("#" + " " * (largeur - 2) + "#")
print("#" * largeur)
print("")
print("╔" + "═" * (largeur - 2) + "╗")
print("║" + " " * (largeur - 2) + "║")
print("╚" + "═" * (largeur - 2) + "╝")
# Out:
# ##########
# #        #
# ##########
#
# ╔════════╗
# ║        ║
# ╚════════╝

# %%
# Angle entre deux points

x1 = 0
y1 = 0
x2 = 1
y2 = 1

angle = math.atan2(y2-y1, x2-x1)
print(math.degrees(angle))
# Out:
# 45.0
