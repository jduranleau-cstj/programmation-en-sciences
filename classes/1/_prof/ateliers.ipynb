# %%
vitesse = 80 # kmh
temps = 30 # minutes

nb_heures = temps / 60
distance = vitesse * nb_heures

print(str(distance) + "km en " + str(temps) + " minutes")
# Out:
# 40.0km en 30 minutes

# %%
age_chat = int(input("Age du chat"))
age_humain = 20 + (age_chat - 1) * 4
print(age_humain)
# Out:
# 36

# %%
prenom = "Julien"
nom = "Duranleau"
sommeil = 8

nom_complet = prenom + " " + nom

phrase = "Mon nom est " + nom_complet + " et j'ai " + str(sommeil) + " heures de sommeil"

print(phrase)
# Out:
# Je m'appel Julien Duranleau et j'ai 8 heures de sommeil

# %%
etapes_completees = 250
nombre_etapes = 500
pourcentage = etapes_completees / nombre_etapes

largeur_barre = 30
nb_plein = int(largeur_barre * pourcentage)
nb_vide = largeur_barre - nb_plein

barre = ("#" * nb_plein) + ("-" * nb_vide)

texte = "Chargement : [" + barre + "]"

print(texte)
# Out:
# Chargement : [###############---------------]
